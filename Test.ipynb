# %% [markdown]
# <a href="https://colab.research.google.com/github/Martipetti/MachineLearning/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Progetto Machine Learning

# %%
import pandas as pd

link = 'http://tennis-data.co.uk/2023/2023.xlsx'
df = pd.read_excel(link)

# %%
from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
df.shape
# Out:
# (2703, 36)

# %%
df
# Out:
#       ATP  Location                Tournament       Date       Series  \
# 0       1  Adelaide  Adelaide International 1 2023-01-01       ATP250
# 1       1  Adelaide  Adelaide International 1 2023-01-01       ATP250
# 2       1  Adelaide  Adelaide International 1 2023-01-02       ATP250
# 3       1  Adelaide  Adelaide International 1 2023-01-02       ATP250
# 4       1  Adelaide  Adelaide International 1 2023-01-02       ATP250
# ...   ...       ...                       ...        ...          ...
# 2698   64     Turin               Masters Cup 2023-11-17  Masters Cup
# 2699   64     Turin               Masters Cup 2023-11-17  Masters Cup
# 2700   64     Turin               Masters Cup 2023-11-18  Masters Cup
# 2701   64     Turin               Masters Cup 2023-11-18  Masters Cup
# 2702   64     Turin               Masters Cup 2023-11-19  Masters Cup
#
#         Court Surface        Round  Best of         Winner  ... Lsets  \
# ...

# %%
from sklearn.utils import shuffle
test_df = shuffle(df)

# %%
test_df
# Out:
#       ATP       Location                                    Tournament  \
# 886    23    Monte Carlo                           Monte Carlo Masters
# 1074   27         Madrid                             Mutua Madrid Open
# 637    18   Indian Wells                              BNP Paribas Open
# 658    18   Indian Wells                              BNP Paribas Open
# 1281   31          Paris                                   French Open
# ...   ...            ...                                           ...
# 729    19          Miami                                    Miami Open
# 867    23    Monte Carlo                           Monte Carlo Masters
# 2097   50  Winston-Salem  Winston-Salem Open at Wake Forest University
# 442    13      Marseille                                       Open 13
# 2340   56       Shanghai                              Shanghai Masters
#
#            Date        Series    Court Surface      Round  Best of  \
# ...

# %%
target = [test_df['Winner'], test_df['Loser']]

# %%
target
# Out:
# [886     Medvedev D.
#  1074       Coric B.
#  637        Fritz T.
#  658      Alcaraz C.
#  1281    Djokovic N.
#             ...
#  729        Halys Q.
#  867     Dimitrov G.
#  2097        Baez S.
#  442         Ymer M.
#  2340     Lajovic D.
#  Name: Winner, Length: 2703, dtype: object,
#  886         Sonego L.
#  1074       Hurkacz H.
#  637        Shelton B.
#  658     Griekspoor T.
#  1281     Kovacevic A.
#              ...
#  729      De Minaur A.
#  867        Shelton B.
#  2097       Lehecka J.
#  442          Albot R.
#  2340      Wawrinka S.
#  Name: Loser, Length: 2703, dtype: object]

# %%
training_set = test_df.drop(columns=['Winner', 'Loser'])

# %%
training_set["Location"] = df["Location"].astype("category")
training_set["Tournament"] = df["Tournament"].astype("category")
training_set["Series"] = df["Series"].astype("category")
training_set["Court"] = df["Court"].astype("category")
training_set["Surface"] = df["Surface"].astype("category")
training_set["Round"] = df["Round"].astype("category")
training_set["Winner"] = df["Winner"].astype("category")
training_set["Winner"] = df["Winner"].astype("category")

# %%
training_set.dtypes
# Out:
# ATP                    int64
# Location            category
# Tournament          category
# Date          datetime64[ns]
# Series              category
# Court               category
# Surface             category
# Round               category
# Best of                int64
# WRank                float64
# LRank                float64
# WPts                 float64
# LPts                 float64
# W1                   float64
# L1                   float64
# W2                   float64
# L2                   float64
# W3                   float64
# L3                   float64
# W4                   float64
# L4                   float64
# W5                   float64
# L5                   float64
# Wsets                float64
# Lsets                float64
# Comment               object
# B365W                float64
# B365L                float64
# PSW                  float64
# PSL                  float64
# MaxW                 float64
# MaxL                 float64
# ...

# %%
model = Sequential([
    Dense(units=136, input_shape=(1,), activation='relu'),
    Dense(units=272, activation='relu'),
    Dense(units=2, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 136)               272
#
#  dense_7 (Dense)             (None, 272)               37264
#
#  dense_8 (Dense)             (None, 2)                 546
#
# ...
# Total params: 38082 (148.76 KB)
# Trainable params: 38082 (148.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#training_set = training_set.to_numpy()

# %%
y_train = keras.utils.to_categorical(training_set)
y_test = keras.utils.to_categorical(target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-3152da870ecc> in <cell line: 1>()
# ----> 1 y_train = keras.utils.to_categorical(training_set)
#       2 y_test = keras.utils.to_categorical(target)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      60     [0. 0. 0. 0.]
#      61     """
# ---> 62     y = np.array(y, dtype="int")
#      63     input_shape = y.shape
#      64
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    2068
#    2069     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070         return np.asarray(self._values, dtype=dtype)
#    2071
#    2072     def __array_wrap__(
#
# ValueError: invalid literal for int() with base 10: 'Monte Carlo'

# %%
2model.fit(x=training_set, y=target, epochs=10, batch_size=50, verbose=2, validation_split=0.1)

# %%
training_set.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-782393ecb36b> in <cell line: 1>()
# ----> 1 training_set.dtypes
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dtypes'
