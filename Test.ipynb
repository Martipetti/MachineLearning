# %% [markdown]
# <a href="https://colab.research.google.com/github/Martipetti/MachineLearning/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Progetto Machine Learning

# %%
import pandas as pd

link = 'http://tennis-data.co.uk/2023/2023.xlsx'
df = pd.read_excel(link)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
df.shape
# Out:
# (2703, 36)

# %%
df
# Out:
#       ATP  Location                Tournament       Date       Series  \
# 0       1  Adelaide  Adelaide International 1 2023-01-01       ATP250
# 1       1  Adelaide  Adelaide International 1 2023-01-01       ATP250
# 2       1  Adelaide  Adelaide International 1 2023-01-02       ATP250
# 3       1  Adelaide  Adelaide International 1 2023-01-02       ATP250
# 4       1  Adelaide  Adelaide International 1 2023-01-02       ATP250
# ...   ...       ...                       ...        ...          ...
# 2698   64     Turin               Masters Cup 2023-11-17  Masters Cup
# 2699   64     Turin               Masters Cup 2023-11-17  Masters Cup
# 2700   64     Turin               Masters Cup 2023-11-18  Masters Cup
# 2701   64     Turin               Masters Cup 2023-11-18  Masters Cup
# 2702   64     Turin               Masters Cup 2023-11-19  Masters Cup
#
#         Court Surface        Round  Best of         Winner  ... Lsets  \
# 0     Outdoor    Hard    1st Round        3       Giron M.  ...   1.0
# 1     Outdoor    Hard    1st Round        3    Mcdonald M.  ...   0.0
# 2     Outdoor    Hard    1st Round        3  Kecmanovic M.  ...   0.0
# 3     Outdoor    Hard    1st Round        3    Nishioka Y.  ...   1.0
# 4     Outdoor    Hard    1st Round        3     Popyrin A.  ...   0.0
# ...       ...     ...          ...      ...            ...  ...   ...
# 2698   Indoor    Hard  Round Robin        3     Alcaraz C.  ...   0.0
# 2699   Indoor    Hard  Round Robin        3      Zverev A.  ...   0.0
# 2700   Indoor    Hard   Semifinals        3      Sinner J.  ...   1.0
# 2701   Indoor    Hard   Semifinals        3    Djokovic N.  ...   0.0
# 2702   Indoor    Hard    The Final        3    Djokovic N.  ...   0.0
#
#         Comment  B365W  B365L   PSW   PSL  MaxW  MaxL  AvgW  AvgL
# 0     Completed   1.91   1.91  1.93  1.95  1.99  1.95  1.89  1.89
# 1       Retired   1.36   3.20  1.39  3.25  1.44  3.40  1.36  3.12
# 2     Completed   1.57   2.38  1.58  2.53  1.64  2.53  1.58  2.36
# 3     Completed   3.75   1.29  4.00  1.28  4.00  1.31  3.56  1.29
# 4     Completed   6.50   1.11  6.20  1.15  6.75  1.18  6.04  1.13
# ...         ...    ...    ...   ...   ...   ...   ...   ...   ...
# 2698  Completed   1.67   2.20  1.78  2.16  1.78  2.30  1.68  2.19
# 2699  Completed   1.62   2.30  1.74  2.23  1.76  2.35  1.66  2.22
# 2700  Completed   1.67   2.20  1.69  2.31  1.71  2.36  1.64  2.26
# 2701  Completed   1.62   2.30  1.67  2.36  1.70  2.43  1.63  2.28
# 2702  Completed   1.53   2.50  1.62  2.45  1.62  2.68  1.55  2.48
#
# [2703 rows x 36 columns]
# Warning: Total number of columns (36) exceeds max_columns (20) limiting to first (20) columns.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['ATP'].plot(kind='hist', bins=20, title='ATP')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Best of'].plot(kind='hist', bins=20, title='Best of')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['WRank'].plot(kind='hist', bins=20, title='WRank')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['LRank'].plot(kind='hist', bins=20, title='LRank')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Series').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Court').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Surface').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Round').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='ATP', y='Best of', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Best of', y='WRank', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='WRank', y='LRank', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='LRank', y='WPts', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Date']
#   ys = series['Best of']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('Date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Series')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Series', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Date')
# _ = plt.ylabel('Best of')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Date']
#   ys = series['Best of']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('Date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Court')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Court', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Date')
# _ = plt.ylabel('Best of')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Date']
#   ys = series['Best of']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('Date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Surface')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Surface', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Date')
# _ = plt.ylabel('Best of')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Date']
#   ys = series['Best of']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('Date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Round')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Round', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Date')
# _ = plt.ylabel('Best of')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['ATP'].plot(kind='line', figsize=(8, 4), title='ATP')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Best of'].plot(kind='line', figsize=(8, 4), title='Best of')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['WRank'].plot(kind='line', figsize=(8, 4), title='WRank')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['LRank'].plot(kind='line', figsize=(8, 4), title='LRank')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Court'].value_counts()
#     for x_label, grp in df.groupby('Series')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Series')
# _ = plt.ylabel('Court')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Surface'].value_counts()
#     for x_label, grp in df.groupby('Court')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Court')
# _ = plt.ylabel('Surface')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Round'].value_counts()
#     for x_label, grp in df.groupby('Surface')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Surface')
# _ = plt.ylabel('Round')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Comment'].value_counts()
#     for x_label, grp in df.groupby('Round')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Round')
# _ = plt.ylabel('Comment')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Series'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='ATP', y='Series', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Court'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='ATP', y='Court', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Surface'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='ATP', y='Surface', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Round'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='ATP', y='Round', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from sklearn.utils import shuffle
test_df = shuffle(df)

# %%
test_df
# Out:
#       ATP      Location                       Tournament       Date  \
# 1930   47    Washington                        Citi Open 2023-08-04
# 2274   53        Zhuhai             Zhuhai Championships 2023-09-24
# 1617   38        London                        Wimbledon 2023-07-06
# 584    18  Indian Wells                 BNP Paribas Open 2023-03-08
# 2111   51      New York                          US Open 2023-08-28
# ...   ...           ...                              ...        ...
# 2690   64         Turin                      Masters Cup 2023-11-13
# 2443   57       Antwerp                    European Open 2023-10-18
# 39      2          Pune                 Maharashtra Open 2023-01-03
# 2425   56      Shanghai                 Shanghai Masters 2023-10-12
# 2486   58         Tokyo  Japan Open Tennis Championships 2023-10-16
#
#             Series    Court Surface          Round  Best of  \
# 1930        ATP500  Outdoor    Hard      3rd Round        3
# 2274        ATP250  Outdoor    Hard  Quarterfinals        3
# 1617    Grand Slam  Outdoor   Grass      2nd Round        5
# 584   Masters 1000  Outdoor    Hard      1st Round        3
# 2111    Grand Slam  Outdoor    Hard      1st Round        5
# ...            ...      ...     ...            ...      ...
# 2690   Masters Cup   Indoor    Hard    Round Robin        3
# 2443        ATP250   Indoor    Hard      1st Round        3
# 39          ATP250  Outdoor    Hard      1st Round        3
# 2425  Masters 1000  Outdoor    Hard  Quarterfinals        3
# 2486        ATP500  Outdoor    Hard      1st Round        3
#
#                     Winner  ... Lsets    Comment  B365W  B365L   PSW   PSL  \
# 1930         Griekspoor T.  ...   1.0  Completed   1.73   2.10  1.78  2.16
# 2274           Karatsev A.  ...   0.0  Completed   2.50   1.53  3.08  1.43
# 1617           Marterer M.  ...   0.0  Completed   1.80   2.00  1.92  1.99
# 584           Nakashima B.  ...   0.0  Completed   1.91   1.91  2.03  1.86
# 2111           Hijikata R.  ...   1.0  Completed   1.73   2.10  1.86  2.05
# ...                    ...  ...   ...        ...    ...    ...   ...   ...
# 2690             Zverev A.  ...   1.0  Completed   2.75   1.44  2.87  1.48
# 2443  Van De Zandschulp B.  ...   1.0  Completed   1.80   2.00  1.95  1.93
# 39             Marterer M.  ...   1.0  Completed   2.10   1.73  2.06  1.83
# 2425            Hurkacz H.  ...   1.0  Completed   1.36   3.20  1.39  3.27
# 2486              Ofner S.  ...   1.0  Completed   1.91   1.91  1.99  1.90
#
#       MaxW  MaxL  AvgW  AvgL
# 1930  1.83  2.16  1.76  2.06
# 2274  3.08  1.57  2.60  1.50
# 1617  1.92  2.05  1.84  1.98
# 584   2.03  1.98  1.95  1.86
# 2111  1.88  2.11  1.79  2.04
# ...    ...   ...   ...   ...
# 2690  2.93  1.50  2.76  1.45
# 2443  1.95  2.02  1.87  1.91
# 39    2.15  1.83  2.04  1.77
# 2425  1.43  3.27  1.37  3.06
# 2486  1.99  1.95  1.91  1.88
#
# [2703 rows x 36 columns]

# %%
target = [test_df['Winner'], test_df['Loser']]

# %%
target
# Out:
# [1930           Griekspoor T.
#  2274             Karatsev A.
#  1617             Marterer M.
#  584             Nakashima B.
#  2111             Hijikata R.
#                  ...
#  2690               Zverev A.
#  2443    Van De Zandschulp B.
#  39               Marterer M.
#  2425              Hurkacz H.
#  2486                Ofner S.
#  Name: Winner, Length: 2703, dtype: object,
#  1930      Monfils G.
#  2274       Norrie C.
#  1617         Mmoh M.
#  584         Isner J.
#  2111        Kotov P.
#              ...
#  2690      Alcaraz C.
#  2443     Stricker D.
#  39           Ymer E.
#  2425     Marozsan F.
#  2486    O Connell C.
#  Name: Loser, Length: 2703, dtype: object]

# %%
training_set = test_df.drop(columns=['Winner', 'Loser'])

# %%
model = Sequential([
    Dense(units=136, input_shape=(1,), activation='relu'),
    Dense(units=272, activation='relu'),
    Dense(units=2, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 136)               272
#
#  dense_1 (Dense)             (None, 272)               37264
#
#  dense_2 (Dense)             (None, 2)                 546
#
# =================================================================
# Total params: 38082 (148.76 KB)
# Trainable params: 38082 (148.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
training_set = training_set.to_numpy()

# %%
y_train = keras.utils.to_categorical(training_set)
y_test = keras.utils.to_categorical(target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-3152da870ecc> in <cell line: 1>()
# ----> 1 y_train = keras.utils.to_categorical(training_set)
#       2 y_test = keras.utils.to_categorical(target)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      60     [0. 0. 0. 0.]
#      61     """
# ---> 62     y = np.array(y, dtype="int")
#      63     input_shape = y.shape
#      64
#
# ValueError: invalid literal for int() with base 10: 'Washington'

# %%
model.fit(x=training_set, y=target, epochs=10, batch_size=50, verbose=2, validation_split=0.1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-62c54d13786f> in <cell line: 1>()
# ----> 1 model.fit(x=training_set, y=target, epochs=10, batch_size=50, verbose=2, validation_split=0.1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     101       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102   ctx.ensure_initialized()
# --> 103   return ops.EagerTensor(value, ctx.device_name, dtype)
#     104
#     105
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type int).
